# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
from datetime import datetime
import time
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "3c3228803934ee3020e8fc7cfcbd0a8f"

# %%
new_lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
new_lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(new_lats,new_lngs)
coordinates = list(lats_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 745

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")


record_count = 1
set_count = 1


for i, city in enumerate(cities):

   
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(65)
  
    city_url = url + "&q=" + city.replace(" ","+")

   
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
      
        city_weather = requests.get(city_url).json()
       
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather['weather'][0]['main']
       
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.

    except: 
        print("City not found...skipping")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | marsa matruh
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | lorengau
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | broome
# Processing Record 7 of Set 1 | aswan
# Processing Record 8 of Set 1 | mumbwa
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | sistranda
# Processing Record 13 of Set 1 | teya
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | marcona
# City not found...skipping
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | shelburne
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | ust-omchug
# Processing Record 22 of Set 1 | souillac
# Processing Record 23 of Set 1 | belushya guba
# City not found...skipping
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | kaitangata
# Processing Record 27 of Set 1 | port hardy
# Processing Record 28 of Set 1 | kavieng
# Processing Record 29 of Set 1 | iqaluit
# Processing Record 30 of Set 1 | lagoa
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | quatre cocos
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | tshikapa
# Processing Record 35 of Set 1 | severo-kurilsk
# Processing Record 36 of Set 1 | husavik
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | hambantota
# Processing Record 42 of Set 1 | san cristobal
# Processing Record 43 of Set 1 | merced
# Processing Record 44 of Set 1 | trat
# Processing Record 45 of Set 1 | port elizabeth
# Processing Record 46 of Set 1 | nguiu
# City not found...skipping
# Processing Record 47 of Set 1 | carnarvon
# Processing Record 48 of Set 1 | lompoc
# Processing Record 49 of Set 1 | lolua
# City not found...skipping
# Processing Record 50 of Set 1 | lebu
# Processing Record 1 of Set 2 | salalah
# Processing Record 2 of Set 2 | hofn
# Processing Record 3 of Set 2 | volax
# Processing Record 4 of Set 2 | dingle
# Processing Record 5 of Set 2 | beringovskiy
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | awbari
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | krasnoyarsk-66
# City not found...skipping
# Processing Record 10 of Set 2 | leningradskiy
# Processing Record 11 of Set 2 | nemuro
# Processing Record 12 of Set 2 | aykhal
# Processing Record 13 of Set 2 | nautla
# Processing Record 14 of Set 2 | khandyga
# Processing Record 15 of Set 2 | grand river south east
# City not found...skipping
# Processing Record 16 of Set 2 | kunashak
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | ostrovnoy
# Processing Record 19 of Set 2 | yumen
# Processing Record 20 of Set 2 | jalu
# Processing Record 21 of Set 2 | puerto ayora
# Processing Record 22 of Set 2 | hibbing
# Processing Record 23 of Set 2 | ancud
# Processing Record 24 of Set 2 | sfantu gheorghe
# Processing Record 25 of Set 2 | the pas
# Processing Record 26 of Set 2 | lazaro cardenas
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | puerto penasco
# Processing Record 29 of Set 2 | khabary
# Processing Record 30 of Set 2 | hamamatsu
# Processing Record 31 of Set 2 | san roque
# Processing Record 32 of Set 2 | nalut
# Processing Record 33 of Set 2 | paamiut
# Processing Record 34 of Set 2 | winnemucca
# Processing Record 35 of Set 2 | mehamn
# Processing Record 36 of Set 2 | nizhneyansk
# City not found...skipping
# Processing Record 37 of Set 2 | namibe
# Processing Record 38 of Set 2 | port lincoln
# Processing Record 39 of Set 2 | avarua
# Processing Record 40 of Set 2 | hopelchen
# Processing Record 41 of Set 2 | saint augustine
# Processing Record 42 of Set 2 | vardo
# Processing Record 43 of Set 2 | teluk nibung
# Processing Record 44 of Set 2 | taolanaro
# City not found...skipping
# Processing Record 45 of Set 2 | baghdad
# Processing Record 46 of Set 2 | lanzhou
# Processing Record 47 of Set 2 | atuona
# Processing Record 48 of Set 2 | fortuna
# Processing Record 49 of Set 2 | norman wells
# Processing Record 50 of Set 2 | paita
# Processing Record 1 of Set 3 | provideniya
# Processing Record 2 of Set 3 | wattegama
# Processing Record 3 of Set 3 | uglegorsk
# Processing Record 4 of Set 3 | port hedland
# Processing Record 5 of Set 3 | korla
# Processing Record 6 of Set 3 | kavaratti
# Processing Record 7 of Set 3 | ranong
# Processing Record 8 of Set 3 | inhambane
# Processing Record 9 of Set 3 | yulara
# Processing Record 10 of Set 3 | ribeira grande
# Processing Record 11 of Set 3 | banda aceh
# Processing Record 12 of Set 3 | cayenne
# Processing Record 13 of Set 3 | kobryn
# Processing Record 14 of Set 3 | alta floresta
# Processing Record 15 of Set 3 | katsuura
# Processing Record 16 of Set 3 | pringsewu
# Processing Record 17 of Set 3 | bozdar
# Processing Record 18 of Set 3 | tommot
# Processing Record 19 of Set 3 | santiago
# Processing Record 20 of Set 3 | tsihombe
# City not found...skipping
# Processing Record 21 of Set 3 | valparaiso
# Processing Record 22 of Set 3 | cherskiy
# Processing Record 23 of Set 3 | kirkwall
# Processing Record 24 of Set 3 | sept-iles
# Processing Record 25 of Set 3 | san isidro
# Processing Record 26 of Set 3 | mys shmidta
# City not found...skipping
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | pallasovka
# Processing Record 29 of Set 3 | zhigansk
# Processing Record 30 of Set 3 | honningsvag
# Processing Record 31 of Set 3 | bokspits
# City not found...skipping
# Processing Record 32 of Set 3 | port moresby
# Processing Record 33 of Set 3 | cabo san lucas
# Processing Record 34 of Set 3 | sorkjosen
# Processing Record 35 of Set 3 | maldonado
# Processing Record 36 of Set 3 | viedma
# Processing Record 37 of Set 3 | ketchikan
# Processing Record 38 of Set 3 | morondava
# Processing Record 39 of Set 3 | dabakala
# Processing Record 40 of Set 3 | flinders
# Processing Record 41 of Set 3 | olafsvik
# Processing Record 42 of Set 3 | illoqqortoormiut
# City not found...skipping
# Processing Record 43 of Set 3 | sinnamary
# Processing Record 44 of Set 3 | pimentel
# Processing Record 45 of Set 3 | harper
# Processing Record 46 of Set 3 | bluff
# Processing Record 47 of Set 3 | sainte-maxime
# Processing Record 48 of Set 3 | bathsheba
# Processing Record 49 of Set 3 | hunza
# City not found...skipping
# Processing Record 50 of Set 3 | torbay
# Processing Record 1 of Set 4 | faanui
# Processing Record 2 of Set 4 | qaanaaq
# Processing Record 3 of Set 4 | cape town
# Processing Record 4 of Set 4 | emirdag
# Processing Record 5 of Set 4 | isangel
# Processing Record 6 of Set 4 | buraydah
# Processing Record 7 of Set 4 | almansa
# Processing Record 8 of Set 4 | cayhagan
# Processing Record 9 of Set 4 | esperance
# Processing Record 10 of Set 4 | gornopravdinsk
# Processing Record 11 of Set 4 | pevek
# Processing Record 12 of Set 4 | kodiak
# Processing Record 13 of Set 4 | vestmanna
# Processing Record 14 of Set 4 | dhupgari
# Processing Record 15 of Set 4 | sao joao da barra
# Processing Record 16 of Set 4 | bay roberts
# Processing Record 17 of Set 4 | bethel
# Processing Record 18 of Set 4 | paharpur
# Processing Record 19 of Set 4 | pangody
# Processing Record 20 of Set 4 | hsinchu
# Processing Record 21 of Set 4 | victoria
# Processing Record 22 of Set 4 | evensk
# Processing Record 23 of Set 4 | linjiang
# Processing Record 24 of Set 4 | dubbo
# Processing Record 25 of Set 4 | pasir mas
# Processing Record 26 of Set 4 | poros
# Processing Record 27 of Set 4 | okha
# Processing Record 28 of Set 4 | margate
# Processing Record 29 of Set 4 | port keats
# Processing Record 30 of Set 4 | noyabrsk
# Processing Record 31 of Set 4 | dovolnoye
# Processing Record 32 of Set 4 | port-gentil
# Processing Record 33 of Set 4 | esna
# Processing Record 34 of Set 4 | chimoio
# Processing Record 35 of Set 4 | huron
# Processing Record 36 of Set 4 | solnechnyy
# Processing Record 37 of Set 4 | biak
# Processing Record 38 of Set 4 | olenino
# Processing Record 39 of Set 4 | tuatapere
# Processing Record 40 of Set 4 | karkaralinsk
# City not found...skipping
# Processing Record 41 of Set 4 | mahibadhoo
# Processing Record 42 of Set 4 | salinopolis
# Processing Record 43 of Set 4 | dunedin
# Processing Record 44 of Set 4 | anaconda
# Processing Record 45 of Set 4 | grindavik
# Processing Record 46 of Set 4 | luan
# Processing Record 47 of Set 4 | laguna
# Processing Record 48 of Set 4 | adrar
# Processing Record 49 of Set 4 | nanortalik
# Processing Record 50 of Set 4 | narsaq
# Processing Record 1 of Set 5 | attawapiskat
# City not found...skipping
# Processing Record 2 of Set 5 | sentyabrskiy
# City not found...skipping
# Processing Record 3 of Set 5 | hilo
# Processing Record 4 of Set 5 | codrington
# Processing Record 5 of Set 5 | petatlan
# Processing Record 6 of Set 5 | saskylakh
# Processing Record 7 of Set 5 | kawana waters
# City not found...skipping
# Processing Record 8 of Set 5 | varhaug
# Processing Record 9 of Set 5 | alofi
# Processing Record 10 of Set 5 | ransang
# Processing Record 11 of Set 5 | honiara
# Processing Record 12 of Set 5 | chokurdakh
# Processing Record 13 of Set 5 | talnakh
# Processing Record 14 of Set 5 | saint george
# Processing Record 15 of Set 5 | sitka
# Processing Record 16 of Set 5 | christchurch
# Processing Record 17 of Set 5 | tabiauea
# City not found...skipping
# Processing Record 18 of Set 5 | kenai
# Processing Record 19 of Set 5 | kamenskoye
# City not found...skipping
# Processing Record 20 of Set 5 | las vegas
# Processing Record 21 of Set 5 | chara
# Processing Record 22 of Set 5 | longyearbyen
# Processing Record 23 of Set 5 | saint anthony
# Processing Record 24 of Set 5 | bonthe
# Processing Record 25 of Set 5 | bekhtery
# Processing Record 26 of Set 5 | south lake tahoe
# Processing Record 27 of Set 5 | san patricio
# Processing Record 28 of Set 5 | usinsk
# Processing Record 29 of Set 5 | mangrol
# Processing Record 30 of Set 5 | mar del plata
# Processing Record 31 of Set 5 | yar-sale
# Processing Record 32 of Set 5 | wanaka
# Processing Record 33 of Set 5 | arlit
# Processing Record 34 of Set 5 | cidreira
# Processing Record 35 of Set 5 | morant bay
# Processing Record 36 of Set 5 | east london
# Processing Record 37 of Set 5 | makinsk
# Processing Record 38 of Set 5 | coihaique
# Processing Record 39 of Set 5 | chapais
# Processing Record 40 of Set 5 | melaka
# Processing Record 41 of Set 5 | meppen
# Processing Record 42 of Set 5 | amderma
# City not found...skipping
# Processing Record 43 of Set 5 | bengkulu
# Processing Record 44 of Set 5 | gisborne
# Processing Record 45 of Set 5 | nyzhnya duvanka
# Processing Record 46 of Set 5 | arraial do cabo
# Processing Record 47 of Set 5 | khatanga
# Processing Record 48 of Set 5 | upernavik
# Processing Record 49 of Set 5 | kadykchan
# City not found...skipping
# Processing Record 50 of Set 5 | san fernando
# Processing Record 1 of Set 6 | kota bahru
# Processing Record 2 of Set 6 | plainview
# Processing Record 3 of Set 6 | fort nelson
# Processing Record 4 of Set 6 | nara
# Processing Record 5 of Set 6 | north bend
# Processing Record 6 of Set 6 | soyaux
# Processing Record 7 of Set 6 | tyup
# Processing Record 8 of Set 6 | batagay
# Processing Record 9 of Set 6 | papenburg
# Processing Record 10 of Set 6 | ayan
# Processing Record 11 of Set 6 | daru
# Processing Record 12 of Set 6 | muros
# Processing Record 13 of Set 6 | carauari
# Processing Record 14 of Set 6 | gorno-chuyskiy
# City not found...skipping
# Processing Record 15 of Set 6 | tutoia
# Processing Record 16 of Set 6 | sorland
# Processing Record 17 of Set 6 | shaunavon
# Processing Record 18 of Set 6 | huarmey
# Processing Record 19 of Set 6 | saint simons
# Processing Record 20 of Set 6 | marawi
# Processing Record 21 of Set 6 | shintomi
# Processing Record 22 of Set 6 | fethiye
# Processing Record 23 of Set 6 | bosaso
# Processing Record 24 of Set 6 | oinofita
# City not found...skipping
# Processing Record 25 of Set 6 | egvekinot
# Processing Record 26 of Set 6 | ulcinj
# Processing Record 27 of Set 6 | santa lucia
# Processing Record 28 of Set 6 | aripuana
# Processing Record 29 of Set 6 | airai
# Processing Record 30 of Set 6 | turayf
# Processing Record 31 of Set 6 | saldanha
# Processing Record 32 of Set 6 | port hawkesbury
# Processing Record 33 of Set 6 | goderich
# Processing Record 34 of Set 6 | monster
# Processing Record 35 of Set 6 | guane
# Processing Record 36 of Set 6 | poum
# Processing Record 37 of Set 6 | havre-saint-pierre
# Processing Record 38 of Set 6 | kroya
# Processing Record 39 of Set 6 | shirokiy
# Processing Record 40 of Set 6 | san jose
# Processing Record 41 of Set 6 | kamuli
# Processing Record 42 of Set 6 | bakewar
# Processing Record 43 of Set 6 | belmonte
# Processing Record 44 of Set 6 | ulundi
# Processing Record 45 of Set 6 | grand haven
# Processing Record 46 of Set 6 | tromso
# Processing Record 47 of Set 6 | manavalakurichi
# Processing Record 48 of Set 6 | barentsburg
# City not found...skipping
# Processing Record 49 of Set 6 | atar
# Processing Record 50 of Set 6 | luderitz
# Processing Record 1 of Set 7 | sankt valentin
# Processing Record 2 of Set 7 | saint-francois
# Processing Record 3 of Set 7 | thompson
# Processing Record 4 of Set 7 | mount isa
# Processing Record 5 of Set 7 | harsin
# Processing Record 6 of Set 7 | lyangasovo
# Processing Record 7 of Set 7 | jinchengjiang
# City not found...skipping
# Processing Record 8 of Set 7 | spirit river
# Processing Record 9 of Set 7 | lavrentiya
# Processing Record 10 of Set 7 | armacao dos buzios
# City not found...skipping
# Processing Record 11 of Set 7 | porto empedocle
# Processing Record 12 of Set 7 | mpika
# Processing Record 13 of Set 7 | bur gabo
# City not found...skipping
# Processing Record 14 of Set 7 | saint-georges
# Processing Record 15 of Set 7 | sinkat
# City not found...skipping
# Processing Record 16 of Set 7 | georgiyevka
# Processing Record 17 of Set 7 | brae
# Processing Record 18 of Set 7 | dongying
# Processing Record 19 of Set 7 | rio claro
# Processing Record 20 of Set 7 | taltal
# Processing Record 21 of Set 7 | angoche
# Processing Record 22 of Set 7 | lahaina
# Processing Record 23 of Set 7 | gradignan
# Processing Record 24 of Set 7 | tiznit
# Processing Record 25 of Set 7 | mbini
# Processing Record 26 of Set 7 | castro
# Processing Record 27 of Set 7 | rosetown
# Processing Record 28 of Set 7 | agadez
# Processing Record 29 of Set 7 | bambous virieux
# Processing Record 30 of Set 7 | tongren
# Processing Record 31 of Set 7 | lasa
# Processing Record 32 of Set 7 | klaksvik
# Processing Record 33 of Set 7 | houma
# Processing Record 34 of Set 7 | manono
# Processing Record 35 of Set 7 | karratha
# Processing Record 36 of Set 7 | ukiah
# Processing Record 37 of Set 7 | qaqortoq
# Processing Record 38 of Set 7 | tawkar
# City not found...skipping
# Processing Record 39 of Set 7 | comodoro rivadavia
# Processing Record 40 of Set 7 | hirara
# Processing Record 41 of Set 7 | mergui
# City not found...skipping
# Processing Record 42 of Set 7 | surt
# Processing Record 43 of Set 7 | vestmannaeyjar
# Processing Record 44 of Set 7 | chaozhou
# Processing Record 45 of Set 7 | sibolga
# Processing Record 46 of Set 7 | vulcan
# Processing Record 47 of Set 7 | satitoa
# City not found...skipping
# Processing Record 48 of Set 7 | plettenberg bay
# Processing Record 49 of Set 7 | vila velha
# Processing Record 50 of Set 7 | alihe
# Processing Record 1 of Set 8 | tripoli
# Processing Record 2 of Set 8 | shenjiamen
# Processing Record 3 of Set 8 | redcar
# Processing Record 4 of Set 8 | nelson bay
# Processing Record 5 of Set 8 | isla mujeres
# Processing Record 6 of Set 8 | almonte
# Processing Record 7 of Set 8 | padang
# Processing Record 8 of Set 8 | draguignan
# Processing Record 9 of Set 8 | tilichiki
# Processing Record 10 of Set 8 | ulagan
# Processing Record 11 of Set 8 | novoshakhtinsk
# Processing Record 12 of Set 8 | sao filipe
# Processing Record 13 of Set 8 | palabuhanratu
# City not found...skipping
# Processing Record 14 of Set 8 | gondar
# Processing Record 15 of Set 8 | churapcha
# Processing Record 16 of Set 8 | hauterive
# Processing Record 17 of Set 8 | montepuez
# Processing Record 18 of Set 8 | ponta do sol
# Processing Record 19 of Set 8 | maniitsoq
# Processing Record 20 of Set 8 | zhezkazgan
# Processing Record 21 of Set 8 | tiksi
# Processing Record 22 of Set 8 | mayo
# Processing Record 23 of Set 8 | san quintin
# Processing Record 24 of Set 8 | balkhash
# Processing Record 25 of Set 8 | kapit
# Processing Record 26 of Set 8 | bogorodskoye
# Processing Record 27 of Set 8 | yuxia
# Processing Record 28 of Set 8 | batagay-alyta
# Processing Record 29 of Set 8 | caravelas
# Processing Record 30 of Set 8 | hammerfest
# Processing Record 31 of Set 8 | aklavik
# Processing Record 32 of Set 8 | havelock
# Processing Record 33 of Set 8 | mount gambier
# Processing Record 34 of Set 8 | pirapo
# Processing Record 35 of Set 8 | vostok
# Processing Record 36 of Set 8 | ambon
# Processing Record 37 of Set 8 | toora-khem
# Processing Record 38 of Set 8 | mathathane
# Processing Record 39 of Set 8 | ust-kuyga
# Processing Record 40 of Set 8 | haines junction
# Processing Record 41 of Set 8 | navolato
# Processing Record 42 of Set 8 | portland
# Processing Record 43 of Set 8 | nola
# Processing Record 44 of Set 8 | kamenka
# Processing Record 45 of Set 8 | pisco
# Processing Record 46 of Set 8 | wad madani
# Processing Record 47 of Set 8 | wadi musa
# Processing Record 48 of Set 8 | dawei
# Processing Record 49 of Set 8 | vallenar
# Processing Record 50 of Set 8 | sarakhs
# Processing Record 1 of Set 9 | parkes
# Processing Record 2 of Set 9 | itamaraju
# Processing Record 3 of Set 9 | ischia
# Processing Record 4 of Set 9 | ploemeur
# Processing Record 5 of Set 9 | marmora
# Processing Record 6 of Set 9 | vysokogornyy
# Processing Record 7 of Set 9 | kargat
# Processing Record 8 of Set 9 | nyurba
# Processing Record 9 of Set 9 | mae sai
# Processing Record 10 of Set 9 | jizan
# Processing Record 11 of Set 9 | rio gallegos
# Processing Record 12 of Set 9 | eureka
# Processing Record 13 of Set 9 | neryungri
# Processing Record 14 of Set 9 | geraldton
# Processing Record 15 of Set 9 | muisne
# Processing Record 16 of Set 9 | pampas
# Processing Record 17 of Set 9 | siemiatycze
# Processing Record 18 of Set 9 | bang saphan
# Processing Record 19 of Set 9 | grover beach
# Processing Record 20 of Set 9 | russell
# Processing Record 21 of Set 9 | la brea
# Processing Record 22 of Set 9 | itarema
# Processing Record 23 of Set 9 | la paz
# Processing Record 24 of Set 9 | batemans bay
# Processing Record 25 of Set 9 | mtwara
# Processing Record 26 of Set 9 | motygino
# Processing Record 27 of Set 9 | johannesburg
# Processing Record 28 of Set 9 | luorong
# Processing Record 29 of Set 9 | raudeberg
# Processing Record 30 of Set 9 | constitucion
# Processing Record 31 of Set 9 | vanderhoof
# Processing Record 32 of Set 9 | touros
# Processing Record 33 of Set 9 | alyangula
# Processing Record 34 of Set 9 | los teques
# Processing Record 35 of Set 9 | coquimbo
# Processing Record 36 of Set 9 | chau doc
# Processing Record 37 of Set 9 | cap malheureux
# Processing Record 38 of Set 9 | pyapon
# Processing Record 39 of Set 9 | qarqin
# Processing Record 40 of Set 9 | larsnes
# Processing Record 41 of Set 9 | dapitan
# Processing Record 42 of Set 9 | kahului
# Processing Record 43 of Set 9 | tungor
# Processing Record 44 of Set 9 | san juan
# Processing Record 45 of Set 9 | rypefjord
# Processing Record 46 of Set 9 | miri
# Processing Record 47 of Set 9 | tongzi
# Processing Record 48 of Set 9 | mollendo
# Processing Record 49 of Set 9 | batticaloa
# Processing Record 50 of Set 9 | miguel hidalgo
# Processing Record 1 of Set 10 | aksu
# Processing Record 2 of Set 10 | shostka
# Processing Record 3 of Set 10 | vila franca do campo
# Processing Record 4 of Set 10 | iskateley
# Processing Record 5 of Set 10 | tasiilaq
# Processing Record 6 of Set 10 | hualmay
# Processing Record 7 of Set 10 | dourbali
# Processing Record 8 of Set 10 | taungdwingyi
# Processing Record 9 of Set 10 | alexandria
# Processing Record 10 of Set 10 | verkhoyansk
# Processing Record 11 of Set 10 | madimba
# Processing Record 12 of Set 10 | biltine
# Processing Record 13 of Set 10 | karauzyak
# City not found...skipping
# Processing Record 14 of Set 10 | ardakan
# Processing Record 15 of Set 10 | faya
# Processing Record 16 of Set 10 | bryan
# Processing Record 17 of Set 10 | ahipara
# Processing Record 18 of Set 10 | douglas
# Processing Record 19 of Set 10 | lata
# Processing Record 20 of Set 10 | kununurra
# Processing Record 21 of Set 10 | somerset east
# Processing Record 22 of Set 10 | palmer
# Processing Record 23 of Set 10 | kosino
# Processing Record 24 of Set 10 | baruun-urt
# Processing Record 25 of Set 10 | saleaula
# City not found...skipping
# Processing Record 26 of Set 10 | yenagoa
# Processing Record 27 of Set 10 | bilibino
# Processing Record 28 of Set 10 | kitimat
# Processing Record 29 of Set 10 | north las vegas
# Processing Record 30 of Set 10 | vaitupu
# City not found...skipping
# Processing Record 31 of Set 10 | dahod
# Processing Record 32 of Set 10 | pasighat
# Processing Record 33 of Set 10 | san jeronimo
# Processing Record 34 of Set 10 | peniche
# Processing Record 35 of Set 10 | gat
# Processing Record 36 of Set 10 | kayerkan
# Processing Record 37 of Set 10 | shingu
# Processing Record 38 of Set 10 | brigantine
# Processing Record 39 of Set 10 | libertador general san martin
# Processing Record 40 of Set 10 | kruisfontein
# Processing Record 41 of Set 10 | turukhansk
# Processing Record 42 of Set 10 | okhotsk
# Processing Record 43 of Set 10 | sakakah
# Processing Record 44 of Set 10 | chicama
# Processing Record 45 of Set 10 | tocopilla
# Processing Record 46 of Set 10 | seoul
# Processing Record 47 of Set 10 | swan river
# Processing Record 48 of Set 10 | port blair
# Processing Record 49 of Set 10 | trindade
# Processing Record 50 of Set 10 | nobres
# Processing Record 1 of Set 11 | tomigusuku
# Processing Record 2 of Set 11 | san diego de la union
# Processing Record 3 of Set 11 | pandan
# Processing Record 4 of Set 11 | guarapari
# Processing Record 5 of Set 11 | jha jha
# Processing Record 6 of Set 11 | arrecife
# Processing Record 7 of Set 11 | gravdal
# Processing Record 8 of Set 11 | poya
# Processing Record 9 of Set 11 | mariental
# Processing Record 10 of Set 11 | sahuaripa
# Processing Record 11 of Set 11 | davila
# Processing Record 12 of Set 11 | kovdor
# Processing Record 13 of Set 11 | bambari
# Processing Record 14 of Set 11 | syamzha
# Processing Record 15 of Set 11 | cheuskiny
# City not found...skipping
# Processing Record 16 of Set 11 | chuy
# Processing Record 17 of Set 11 | havoysund
# Processing Record 18 of Set 11 | saiha
# Processing Record 19 of Set 11 | kirakira
# Processing Record 20 of Set 11 | omboue
# Processing Record 21 of Set 11 | ponta delgada
# Processing Record 22 of Set 11 | abu jubayhah
# City not found...skipping
# Processing Record 23 of Set 11 | lakes entrance
# Processing Record 24 of Set 11 | nekhayevskiy
# Processing Record 25 of Set 11 | bisho
# Processing Record 26 of Set 11 | warora
# Processing Record 27 of Set 11 | ensley
# Processing Record 28 of Set 11 | juegang
# Processing Record 29 of Set 11 | lar
# Processing Record 30 of Set 11 | strezhevoy
# Processing Record 31 of Set 11 | bayanday
# Processing Record 32 of Set 11 | bardiyah
# Processing Record 33 of Set 11 | nhulunbuy
# Processing Record 34 of Set 11 | sangar
# Processing Record 35 of Set 11 | tocantins
# Processing Record 36 of Set 11 | nome
# Processing Record 37 of Set 11 | svetlogorsk
# Processing Record 38 of Set 11 | lagdo
# Processing Record 39 of Set 11 | jeremie
# Processing Record 40 of Set 11 | opuwo
# Processing Record 41 of Set 11 | veere
# Processing Record 42 of Set 11 | beyneu
# Processing Record 43 of Set 11 | makakilo city
# Processing Record 44 of Set 11 | rocha
# Processing Record 45 of Set 11 | komsomolskiy
# Processing Record 46 of Set 11 | qasigiannguit
# Processing Record 47 of Set 11 | hasaki
# Processing Record 48 of Set 11 | matara
# Processing Record 49 of Set 11 | shubarkuduk
# Processing Record 50 of Set 11 | almenara
# Processing Record 1 of Set 12 | kalmunai
# Processing Record 2 of Set 12 | lebyazhye
# Processing Record 3 of Set 12 | cuamba
# Processing Record 4 of Set 12 | santa maria
# Processing Record 5 of Set 12 | balikpapan
# Processing Record 6 of Set 12 | cockburn town
# Processing Record 7 of Set 12 | ilulissat
# Processing Record 8 of Set 12 | boyolangu
# Processing Record 9 of Set 12 | casper
# Processing Record 10 of Set 12 | sochi
# Processing Record 11 of Set 12 | srednekolymsk
# Processing Record 12 of Set 12 | iwanai
# Processing Record 13 of Set 12 | sao jose da coroa grande
# Processing Record 14 of Set 12 | adwa
# Processing Record 15 of Set 12 | marzuq
# Processing Record 16 of Set 12 | sorvag
# City not found...skipping
# Processing Record 17 of Set 12 | matagami
# Processing Record 18 of Set 12 | guerrero negro
# Processing Record 19 of Set 12 | khani
# Processing Record 20 of Set 12 | forbes
# Processing Record 21 of Set 12 | ushtobe
# Processing Record 22 of Set 12 | texarkana
# Processing Record 23 of Set 12 | te anau
# Processing Record 24 of Set 12 | coahuayana
# Processing Record 25 of Set 12 | vanimo
# Processing Record 26 of Set 12 | teacapan
# Processing Record 27 of Set 12 | samusu
# City not found...skipping
# Processing Record 28 of Set 12 | shvartsevskiy
# Processing Record 29 of Set 12 | corinth
# Processing Record 30 of Set 12 | zhireken
# Processing Record 31 of Set 12 | sisimiut
# Processing Record 32 of Set 12 | hihifo
# City not found...skipping
# Processing Record 33 of Set 12 | kiama
# Processing Record 34 of Set 12 | puerto carreno
# Processing Record 35 of Set 12 | staroaleyskoye
# Processing Record 36 of Set 12 | rawson
# Processing Record 37 of Set 12 | nakskov
# Processing Record 38 of Set 12 | bobo dioulasso
# Processing Record 39 of Set 12 | altay
# Processing Record 40 of Set 12 | umm lajj
# Processing Record 41 of Set 12 | asau
# Processing Record 42 of Set 12 | cayon
# Processing Record 43 of Set 12 | tsiroanomandidy
# Processing Record 44 of Set 12 | rungata
# City not found...skipping
# Processing Record 45 of Set 12 | mahadday weyne
# City not found...skipping
# Processing Record 46 of Set 12 | ballina
# Processing Record 47 of Set 12 | belyy yar
# Processing Record 48 of Set 12 | aranos
# Processing Record 49 of Set 12 | machico
# Processing Record 50 of Set 12 | manokwari
# Processing Record 1 of Set 13 | atasu
# Processing Record 2 of Set 13 | yambio
# Processing Record 3 of Set 13 | moranbah
# Processing Record 4 of Set 13 | rantepao
# Processing Record 5 of Set 13 | tapes
# Processing Record 6 of Set 13 | meulaboh
# Processing Record 7 of Set 13 | hamilton
# Processing Record 8 of Set 13 | mitu
# Processing Record 9 of Set 13 | saint-augustin
# Processing Record 10 of Set 13 | kasane
# Processing Record 11 of Set 13 | the valley
# Processing Record 12 of Set 13 | kulhudhuffushi
# Processing Record 13 of Set 13 | pozo colorado
# Processing Record 14 of Set 13 | fairbanks
# Processing Record 15 of Set 13 | narrabri
# Processing Record 16 of Set 13 | marrakesh
# Processing Record 17 of Set 13 | rodos
# Processing Record 18 of Set 13 | massaguet
# Processing Record 19 of Set 13 | pacifica
# Processing Record 20 of Set 13 | kuanshan
# City not found...skipping
# Processing Record 21 of Set 13 | mareeba
# Processing Record 22 of Set 13 | soyo
# Processing Record 23 of Set 13 | karaul
# City not found...skipping
# Processing Record 24 of Set 13 | babynino
# Processing Record 25 of Set 13 | haicheng
# Processing Record 26 of Set 13 | ayolas
# Processing Record 27 of Set 13 | stornoway
# Processing Record 28 of Set 13 | tautira
# Processing Record 29 of Set 13 | liku
# Processing Record 30 of Set 13 | borogontsy
# Processing Record 31 of Set 13 | steamboat springs
# Processing Record 32 of Set 13 | hit
# Processing Record 33 of Set 13 | northam
# Processing Record 34 of Set 13 | pochutla
# Processing Record 35 of Set 13 | wulanhaote
# City not found...skipping
# Processing Record 36 of Set 13 | ahuimanu
# Processing Record 37 of Set 13 | huilong
# Processing Record 38 of Set 13 | jatiroto
# Processing Record 39 of Set 13 | menongue
# Processing Record 40 of Set 13 | pangnirtung
# Processing Record 41 of Set 13 | tanout
# Processing Record 42 of Set 13 | grand centre
# City not found...skipping
# Processing Record 43 of Set 13 | shizunai
# Processing Record 44 of Set 13 | namatanai
# Processing Record 45 of Set 13 | vagur
# Processing Record 46 of Set 13 | sargatskoye
# Processing Record 47 of Set 13 | high level
# Processing Record 48 of Set 13 | mackay
# Processing Record 49 of Set 13 | synya
# Processing Record 50 of Set 13 | grimshaw
# Processing Record 1 of Set 14 | santa ana
# Processing Record 2 of Set 14 | topeka
# Processing Record 3 of Set 14 | shagonar
# Processing Record 4 of Set 14 | matay
# Processing Record 5 of Set 14 | ivanava
# Processing Record 6 of Set 14 | uwayl
# City not found...skipping
# Processing Record 7 of Set 14 | jumla
# Processing Record 8 of Set 14 | lang suan
# Processing Record 9 of Set 14 | kabrai
# Processing Record 10 of Set 14 | kungurtug
# Processing Record 11 of Set 14 | kutum
# Processing Record 12 of Set 14 | barra do garcas
# Processing Record 13 of Set 14 | kyabe
# Processing Record 14 of Set 14 | flin flon
# Processing Record 15 of Set 14 | sao raimundo das mangabeiras
# Processing Record 16 of Set 14 | hunchun
# Processing Record 17 of Set 14 | kijaba
# City not found...skipping
# Processing Record 18 of Set 14 | skeldon
# Processing Record 19 of Set 14 | kerema
# Processing Record 20 of Set 14 | sokoni
# Processing Record 21 of Set 14 | skelleftea
# Processing Record 22 of Set 14 | bethlehem
# Processing Record 23 of Set 14 | daryapur
# Processing Record 24 of Set 14 | tabas
# Processing Record 25 of Set 14 | bam
# Processing Record 26 of Set 14 | kudahuvadhoo
# Processing Record 27 of Set 14 | pa sang
# Processing Record 28 of Set 14 | ekibastuz
# Processing Record 29 of Set 14 | glendive
# Processing Record 30 of Set 14 | hirado
# Processing Record 31 of Set 14 | alugan
# Processing Record 32 of Set 14 | cordoba
# Processing Record 33 of Set 14 | trinidad
# Processing Record 34 of Set 14 | yerofey pavlovich
# Processing Record 35 of Set 14 | uchkeken
# Processing Record 36 of Set 14 | healesville
# Processing Record 37 of Set 14 | santa rosa
# Processing Record 38 of Set 14 | zhangye
# Processing Record 39 of Set 14 | dongling
# Processing Record 40 of Set 14 | inderka
# Processing Record 41 of Set 14 | oktyabrskiy
# Processing Record 42 of Set 14 | charters towers
# Processing Record 43 of Set 14 | mlalo
# Processing Record 44 of Set 14 | mocajuba
# Processing Record 45 of Set 14 | los llanos de aridane
# Processing Record 46 of Set 14 | bubaque
# Processing Record 47 of Set 14 | myaundzha
# Processing Record 48 of Set 14 | ormara
# Processing Record 49 of Set 14 | okahandja
# Processing Record 50 of Set 14 | san vicente
# Processing Record 1 of Set 15 | dali
# Processing Record 2 of Set 15 | antofagasta
# Processing Record 3 of Set 15 | trebisov
# Processing Record 4 of Set 15 | amapa
# Processing Record 5 of Set 15 | naron
# Processing Record 6 of Set 15 | savinka
# Processing Record 7 of Set 15 | capreol
# Processing Record 8 of Set 15 | bilma
# Processing Record 9 of Set 15 | chlorakas
# Processing Record 10 of Set 15 | puerto madryn
# Processing Record 11 of Set 15 | sobolevo
# Processing Record 12 of Set 15 | machiques
# Processing Record 13 of Set 15 | ivanivka
# Processing Record 14 of Set 15 | kuusamo
# Processing Record 15 of Set 15 | kokopo
# Processing Record 16 of Set 15 | ashqelon
# Processing Record 17 of Set 15 | arbagar
# Processing Record 18 of Set 15 | kloulklubed
# Processing Record 19 of Set 15 | aporawan
# City not found...skipping
# Processing Record 20 of Set 15 | vila
# Processing Record 21 of Set 15 | susanville
# Processing Record 22 of Set 15 | tigre
# Processing Record 23 of Set 15 | speightstown
# Processing Record 24 of Set 15 | mizpe ramon
# City not found...skipping
# Processing Record 25 of Set 15 | tucuman
# Processing Record 26 of Set 15 | diego de almagro
# Processing Record 27 of Set 15 | xining
# Processing Record 28 of Set 15 | booue
# Processing Record 29 of Set 15 | atherton
# Processing Record 30 of Set 15 | yibin
# Processing Record 31 of Set 15 | kysyl-syr
# Processing Record 32 of Set 15 | kenora
# Processing Record 33 of Set 15 | uyuni
# Processing Record 34 of Set 15 | gari
# Processing Record 35 of Set 15 | ambulu
# Processing Record 36 of Set 15 | majene
# Processing Record 37 of Set 15 | sao miguel do araguaia
# Processing Record 38 of Set 15 | kegayli
# City not found...skipping
# Processing Record 39 of Set 15 | abu samrah
# Processing Record 40 of Set 15 | letnyaya stavka
# Processing Record 41 of Set 15 | beloha
# Processing Record 42 of Set 15 | barabash
# Processing Record 43 of Set 15 | ondjiva
# Processing Record 44 of Set 15 | tukrah
# Processing Record 45 of Set 15 | bombay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file, index_label="City_ID")
